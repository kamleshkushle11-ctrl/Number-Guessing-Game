# %% [markdown]
# # 🎯 Number Guessing Game
# - `A fun Python mini project where you guess a number between 1 and 100 with helpful hints.

# %% [markdown]
# ## 🔍 How It Works
# - The computer picks a random number between 1 and 100.
# - You guess the number.
# - The game gives hints: "Too high", "Too low", or "Very close!"
# - It tracks how many attempts you take.

# %% [markdown]
# ## ▶️ How to Run
# Just run the cell below and follow the prompts!

# %%
def number_guessing_game():
    number = random.randint(1, 100)
    attempts = 0

    print(" Welcome to the Number Guessing Game.💭")
    print("I'm thinking of a number between 1 and 100.")

    while True:
        guess = input("Take a guess: ")

        if not guess.isdigit():
            print("Please enter a valid number.")
            continue

        guess = int(guess)
        attempts += 1

        if guess == number:
            print(f"🎉 Correct! You guessed it in {attempts} tries.")
            break
        elif abs(guess - number) <= 5:
            print("🔥 Very close!")
        elif guess < number:
            print("📉 Too low.")
        else:
            print("📈 Too high.")

# Run the game
number_guessing_game()
# Out:
#  Welcome to the Number Guessing Game.
# I'm thinking of a number between 1 and 100.
# Take a guess:  25
# 📉 Too low.
# Take a guess:  55
# 📉 Too low.
# Take a guess:  100
# 📈 Too high.
# Take a guess:  80
# 📈 Too high.
# Take a guess:  70
# Take a guess:
# 🔥 Very close!
# Please enter a valid number.
# Take a guess:  72
# 🔥 Very close!
# Take a guess:  71
# 🎉 Correct! You guessed it in 7 tries.

# %% [markdown]
# ## ✅ Done!
# Thanks for playing! Try again and beat your score!
